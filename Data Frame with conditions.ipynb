# %% [markdown]
# # A different Data Set

# %% [markdown]
# Based on the name Kelahiran Bayi_Jakarta_2020, I assume it is a dataset or file related to the births of babies in Jakarta, Indonesia, for the year 2020.

# %%
import pandas as pd

# %%
df = pd.read_csv('Kelahiran Bayi_Jakarta_2020.csv')

# %%
df.head()
# Out:
#    tahun  bulan         kota_kabupaten                 kecamatan  \
# 0   2020      1  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      1  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      1  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      1  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      1  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            kelurahan jenis_kelamin  jumlah  periode_data
# 0     PULAU PANGGANG     Laki-Laki       5          2020
# 1       PULAU KELAPA     Laki-Laki       1          2020
# 2      PULAU HARAPAN     Laki-Laki       1          2020
# 3  PULAU UNTUNG JAWA     Laki-Laki       2          2020
# 4       PULAU TIDUNG     Laki-Laki       2          2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tahun           6408 non-null   int64
#  1   bulan           6408 non-null   int64
#  2   kota_kabupaten  6408 non-null   object
#  3   kecamatan       6408 non-null   object
#  4   kelurahan       6408 non-null   object
#  5   jenis_kelamin   6408 non-null   object
#  6   jumlah          6408 non-null   int64
#  7   periode_data    6408 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 400.6+ KB

# %%
#The following code calls to see the number of non null data

df.notnull().sum()
# Out:
# tahun             6408
# bulan             6408
# kota_kabupaten    6408
# kecamatan         6408
# kelurahan         6408
# jenis_kelamin     6408
# jumlah            6408
# periode_data      6408
# dtype: int64

# %%
#The following code calls to see the number of nulls in the data

df.isnull().sum()
# Out:
# tahun             0
# bulan             0
# kota_kabupaten    0
# kecamatan         0
# kelurahan         0
# jenis_kelamin     0
# jumlah            0
# periode_data      0
# dtype: int64

# %%
#The following code is to see the order of the bottom data

df.tail()
# Out:
#       tahun  bulan kota_kabupaten kecamatan     kelurahan jenis_kelamin  \
# 6403   2020     12  JAKARTA TIMUR  CIPAYUNG        MUNJUL     Perempuan
# 6404   2020     12  JAKARTA TIMUR  CIPAYUNG          SETU     Perempuan
# 6405   2020     12  JAKARTA TIMUR  CIPAYUNG    BAMBU APUS     Perempuan
# 6406   2020     12  JAKARTA TIMUR  CIPAYUNG  LUBANG BUAYA     Perempuan
# 6407   2020     12  JAKARTA TIMUR  CIPAYUNG         CEGER     Perempuan
#
#       jumlah  periode_data
# 6403      23          2020
# 6404      20          2020
# 6405      22          2020
# 6406     100          2020
# 6407      16          2020

# %%
#The following code displays information from columns in the form of numbers

df.describe()
# Out:
#         tahun        bulan       jumlah  periode_data
# count  6408.0  6408.000000  6408.000000        6408.0
# mean   2020.0     6.500000    21.404650        2020.0
# std       0.0     3.452322    18.487518           0.0
# min    2020.0     1.000000     0.000000        2020.0
# 25%    2020.0     3.750000     9.000000        2020.0
# 50%    2020.0     6.500000    17.000000        2020.0
# 75%    2020.0     9.250000    29.000000        2020.0
# max    2020.0    12.000000   178.000000        2020.0

# %%
#for example displays the average of the Amount column

df['jumlah'].mean()
# Out:
# 21.40465043695381

# %%
#for example displays the median of the Number column

df['jumlah'].median()
# Out:
# 17.0

# %%
#for example displays the mode of the Number column

df['jumlah'].mode()[0]
# Out:
# 10

# %%
# see the number of rows and number of columns

df.shape
# Out:
# (6408, 8)

# %%
# see the columns

df.columns
# Out:
# Index(['tahun', 'bulan', 'kota_kabupaten', 'kecamatan', 'kelurahan',
#        'jenis_kelamin', 'jumlah', 'periode_data'],
#       dtype='object')

# %%
#for example looking at NaN from the Number column

df[df['jumlah'].isnull()]
# Out:
# Empty DataFrame
# Columns: [tahun, bulan, kota_kabupaten, kecamatan, kelurahan, jenis_kelamin, jumlah, periode_data]
# Index: []

# %%
#then we mask

[df.jumlah.isnull()] 

#for example looking at NaN from the Number column
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  6403    False
#  6404    False
#  6405    False
#  6406    False
#  6407    False
#  Name: jumlah, Length: 6408, dtype: bool]

# %%
#for example, looking at unique data from the gender_gender column

df.jenis_kelamin.unique()
# Out:
# array(['Laki-Laki', 'Perempuan'], dtype=object)

# %%
#see the number of uniques in the gender_column

df.jenis_kelamin.nunique()
# Out:
# 2

# %%
#see the number of uniques in the kota_kabupaten column

df['kota_kabupaten'].unique()
# Out:
# array(['ADM. KEPULAUAN SERIBU', 'JAKARTA PUSAT', 'JAKARTA UTARA',
#        'JAKARTA BARAT', 'JAKARTA SELATAN', 'JAKARTA TIMUR'], dtype=object)

# %%
#see the number of uniques in the gender_column

df.kota_kabupaten.nunique()#melihat jumah unique dalam column jenis_kelamin
# Out:
# 6

# %%
#see the proportion of the gender_column

df.jenis_kelamin.value_counts()
# Out:
# jenis_kelamin
# Laki-Laki    3204
# Perempuan    3204
# Name: count, dtype: int64

# %%
#how to call a specific column

df[['kecamatan','kelurahan', 'jenis_kelamin', 'jumlah']] #cara memanggil column tertentu
# Out:
#                      kecamatan          kelurahan jenis_kelamin  jumlah
# 0       KEPULAUAN SERIBU UTARA     PULAU PANGGANG     Laki-Laki       5
# 1       KEPULAUAN SERIBU UTARA       PULAU KELAPA     Laki-Laki       1
# 2       KEPULAUAN SERIBU UTARA      PULAU HARAPAN     Laki-Laki       1
# 3     KEPULAUAN SERIBU SELATAN  PULAU UNTUNG JAWA     Laki-Laki       2
# 4     KEPULAUAN SERIBU SELATAN       PULAU TIDUNG     Laki-Laki       2
# ...                        ...                ...           ...     ...
# 6403                  CIPAYUNG             MUNJUL     Perempuan      23
# 6404                  CIPAYUNG               SETU     Perempuan      20
# 6405                  CIPAYUNG         BAMBU APUS     Perempuan      22
# 6406                  CIPAYUNG       LUBANG BUAYA     Perempuan     100
# 6407                  CIPAYUNG              CEGER     Perempuan      16
#
# [6408 rows x 4 columns]

# %%
#call column number whose value is 2

df[df['jumlah']==2]
# Out:
#       tahun  bulan         kota_kabupaten                 kecamatan  \
# 3      2020      1  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4      2020      1  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 12     2020      1          JAKARTA PUSAT               SAWAH BESAR
# 25     2020      1          JAKARTA PUSAT                 S E N E N
# 37     2020      1          JAKARTA PUSAT                   MENTENG
# ...     ...    ...                    ...                       ...
# 6146   2020     12  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 6178   2020     12          JAKARTA PUSAT                   MENTENG
# 6285   2020     12        JAKARTA SELATAN                SETIA BUDI
# 6286   2020     12        JAKARTA SELATAN                SETIA BUDI
# 6320   2020     12        JAKARTA SELATAN            KEBAYORAN BARU
#
#               kelurahan jenis_kelamin  jumlah  periode_data
# 3     PULAU UNTUNG JAWA     Laki-Laki       2          2020
# ...

# %%
#call month columns that are more than 5

df[df['bulan']>5]
# Out:
#       tahun  bulan kota_kabupaten kecamatan      kelurahan jenis_kelamin  \
# 2572   2020      6  JAKARTA BARAT   TAMBORA      KERENDANG     Laki-Laki
# 2573   2020      6  JAKARTA BARAT   TAMBORA  JEMBATAN BESI     Laki-Laki
# 2574   2020      6  JAKARTA BARAT   TAMBORA          ANGKE     Laki-Laki
# 2575   2020      6  JAKARTA BARAT   TAMBORA  JEMBATAN LIMA     Laki-Laki
# 2576   2020      6  JAKARTA BARAT   TAMBORA        PEKOJAN     Laki-Laki
# ...     ...    ...            ...       ...            ...           ...
# 6403   2020     12  JAKARTA TIMUR  CIPAYUNG         MUNJUL     Perempuan
# 6404   2020     12  JAKARTA TIMUR  CIPAYUNG           SETU     Perempuan
# 6405   2020     12  JAKARTA TIMUR  CIPAYUNG     BAMBU APUS     Perempuan
# 6406   2020     12  JAKARTA TIMUR  CIPAYUNG   LUBANG BUAYA     Perempuan
# 6407   2020     12  JAKARTA TIMUR  CIPAYUNG          CEGER     Perempuan
#
#       jumlah  periode_data
# 2572      18          2020
# 2573      33          2020
# ...

# %%
#call the month column that is less than equal to 5

df[~(df['bulan']<5)]
# Out:
#       tahun  bulan         kota_kabupaten                 kecamatan  \
# 1930   2020      5  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1931   2020      5  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1932   2020      5  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1933   2020      5  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 1934   2020      5  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# ...     ...    ...                    ...                       ...
# 6403   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6404   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6405   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6406   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6407   2020     12          JAKARTA TIMUR                  CIPAYUNG
#
#               kelurahan jenis_kelamin  jumlah  periode_data
# 1930     PULAU PANGGANG     Laki-Laki       2          2020
# ...

# %%
#call the month column more than 5 and the gender is female

df[(df['bulan']>5) & (df['jenis_kelamin'] =='Perempuan')]
# Out:
#       tahun  bulan         kota_kabupaten                 kecamatan  \
# 2733   2020      6  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2734   2020      6  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2735   2020      6  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2736   2020      6  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 2737   2020      6  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# ...     ...    ...                    ...                       ...
# 6403   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6404   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6405   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6406   2020     12          JAKARTA TIMUR                  CIPAYUNG
# 6407   2020     12          JAKARTA TIMUR                  CIPAYUNG
#
#               kelurahan jenis_kelamin  jumlah  periode_data
# 2733     PULAU PANGGANG     Perempuan       7          2020
# ...

# %%
#call the month column more than 5 or female gender

df[(df['bulan']>5) | (df['jenis_kelamin'] =='Perempuan')]
# Out:
#       tahun  bulan kota_kabupaten kecamatan              kelurahan  \
# 259    2020      1  JAKARTA TIMUR   MAKASAR  HALIM PERDANA KUSUMAH
# 260    2020      1  JAKARTA TIMUR   MAKASAR        CIPINANG MELAYU
# 261    2020      1  JAKARTA TIMUR   CIRACAS                CIRACAS
# 262    2020      1  JAKARTA TIMUR   CIRACAS                CIBUBUR
# 263    2020      1  JAKARTA TIMUR   CIRACAS       KELAPA DUA WETAN
# ...     ...    ...            ...       ...                    ...
# 6403   2020     12  JAKARTA TIMUR  CIPAYUNG                 MUNJUL
# 6404   2020     12  JAKARTA TIMUR  CIPAYUNG                   SETU
# 6405   2020     12  JAKARTA TIMUR  CIPAYUNG             BAMBU APUS
# 6406   2020     12  JAKARTA TIMUR  CIPAYUNG           LUBANG BUAYA
# 6407   2020     12  JAKARTA TIMUR  CIPAYUNG                  CEGER
#
#      jenis_kelamin  jumlah  periode_data
# 259      Perempuan       3          2020
# 260      Perempuan      11          2020
# ...

# %%
# call the month column whose value is between 5 and 10

df[((df['bulan']>5) & (df['bulan']<10))]
# Out:
#       tahun  bulan   kota_kabupaten       kecamatan         kelurahan  \
# 2572   2020      6    JAKARTA BARAT         TAMBORA         KERENDANG
# 2573   2020      6    JAKARTA BARAT         TAMBORA     JEMBATAN BESI
# 2574   2020      6    JAKARTA BARAT         TAMBORA             ANGKE
# 2575   2020      6    JAKARTA BARAT         TAMBORA     JEMBATAN LIMA
# 2576   2020      6    JAKARTA BARAT         TAMBORA           PEKOJAN
# ...     ...    ...              ...             ...               ...
# 4865   2020      9  JAKARTA SELATAN        CILANDAK  GANDARIA SELATAN
# 4866   2020      9  JAKARTA SELATAN        CILANDAK    CIPETE SELATAN
# 4867   2020      9  JAKARTA SELATAN  KEBAYORAN BARU           MELAWAI
# 4868   2020      9  JAKARTA SELATAN  KEBAYORAN BARU            GUNUNG
# 4869   2020      9  JAKARTA SELATAN  KEBAYORAN BARU       KRAMAT PELA
#
#      jenis_kelamin  jumlah  periode_data
# 2572     Laki-Laki      18          2020
# 2573     Laki-Laki      33          2020
# ...

# %%
df[['kota_kabupaten','kelurahan', 'jenis_kelamin', 'jumlah']][df['jumlah']>20 | (df['jenis_kelamin'] =='Laki-Laki')]
# Out:
#              kota_kabupaten          kelurahan jenis_kelamin  jumlah
# 0     ADM. KEPULAUAN SERIBU     PULAU PANGGANG     Laki-Laki       5
# 3     ADM. KEPULAUAN SERIBU  PULAU UNTUNG JAWA     Laki-Laki       2
# 4     ADM. KEPULAUAN SERIBU       PULAU TIDUNG     Laki-Laki       2
# 5     ADM. KEPULAUAN SERIBU         PULAU PARI     Laki-Laki       4
# 7             JAKARTA PUSAT             CIDENG     Laki-Laki       4
# ...                     ...                ...           ...     ...
# 6403          JAKARTA TIMUR             MUNJUL     Perempuan      23
# 6404          JAKARTA TIMUR               SETU     Perempuan      20
# 6405          JAKARTA TIMUR         BAMBU APUS     Perempuan      22
# 6406          JAKARTA TIMUR       LUBANG BUAYA     Perempuan     100
# 6407          JAKARTA TIMUR              CEGER     Perempuan      16
#
# [6135 rows x 4 columns]
